# %% [markdown]
# <a href="https://colab.research.google.com/github/Kevo1906/Pawpularity_Contest/blob/main/Petfinder_Model_%2B_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile

# Unziping the downloaded file
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Projects/Pawpularity Contest/Data/petfinder-pawpularity-score.zip", "r")
zip_ref.extractall("./Data/")
zip_ref.close()

# %%
import os

for dir_path, dir_names, file_names in os.walk("/content/Data/"):
  print(f'There are {len(dir_names)} directories and {len(file_names)} files in {dir_path} ')
# Out:
# There are 2 directories and 3 files in /content/Data/
# There are 0 directories and 9912 files in /content/Data/train
# There are 0 directories and 8 files in /content/Data/test

# %%
# Creating a function to visualize a random image from the train data
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
import pandas as pd

def view_random_image(target_dir):
  df = pd.read_csv("/content/Data/train.csv")
  
  random_image = random.sample(os.listdir(target_dir),1)
  pawpularity = df[(df["Id"] == random_image[0])]["Pawpularity"]

  img = mpimg.imread(target_dir + "/" + random_image[0])
  plt.imshow(img)
  plt.title(f"Pawpularity: {pawpularity}")
  plt.axis("off")

  return img.shape

df = pd.read_csv("/content/Data/train.csv")
df.head()
pawpularity = df[(df["Id"] == "0007de18844b0dbbb5e1f607da0606e0")]["Pawpularity"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-3d8cef9258c1> in <module>()
#      21 df.head()
#      22 pawpularity = df[(df["Id"] == "0007de18844b0dbbb5e1f607da0606e0")]["Pawpularity"]
# ---> 23 dtype(pawpularity)
#
# NameError: name 'dtype' is not defined

# %%
view_random_image("/content/Data/train")
# Out:
# (960, 720, 3)
